# %%
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

# %%
x = np.array([12, 5, 53, 24, 35])
#px.line(x=[0, 1, 2, 3, 4], y=x, title='Line chart demo') # line chart
#px.bar(x=[0, 1, 2, 3, 4], y=x, title='Bar chart demo') # bar chart
#px.area(x=[0, 1, 2, 3, 4], y=x, title='Area chart demo') # area chart

px.area(x=[1, 2, 3, 4, 5],
        y=x,
        title='Area chart demo',
        labels={'x':'x-axis', 'y':'y-axis'},
        template='plotly_dark',
)

# %%
a = np.random.uniform(0, 1, 100)
b = np.random.uniform(0, 1, 100)
c = np.random.uniform(0, 1, 100)
px.scatter_3d(
    x=a,
    y=b,
    z=c,
    title='Area chart demo',
    labels={'x':'x-axis', 'y':'y-axis'},
    template='plotly_dark',
)
